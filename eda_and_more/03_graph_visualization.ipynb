# %% [markdown]
# # 03 Graph Visualization
#
# This notebook summarizes graph connectivity patterns and highlights highly connected entities.

# %% [markdown]
# ## Analysis Focus
#
# - highly connected entities
# - repeated relationship patterns
# - org distribution in graph results
# - hub-like nodes

# %%
from collections import Counter
import json
from pathlib import Path

query4 = json.load(open(Path('../output/query4_fan_out_by_edge_class.json')))
query4
# Out:
# [{'entity': {'entityType': 'policy',
#    'entityId': 'POL-002',
#    'title': 'Infection Prevention and Control Policy',
#    'orgId': 'ORG-MCLEOD-MAIN'},
#   'countsByEdgeClass': {'operational': 12},
#   'totalEdgeCount': 12},
#  {'entity': {'entityType': 'standard',
#    'entityId': 'STD-002',
#    'title': 'IC.1 SR.1 — Infection Prevention Program',
#    'orgId': 'ORG-MCLEOD-MAIN'},
#   'countsByEdgeClass': {'operational': 10},
#   'totalEdgeCount': 10},
#  {'entity': {'entityType': 'finding',
#    'entityId': 'FND-001',
#    'title': 'Incomplete credentialing files for three locum tenens physicians',
#    'orgId': 'ORG-MCLEOD-MAIN'},
#   'countsByEdgeClass': {'operational': 8},
#   'totalEdgeCount': 8},
#  {'entity': {'entityType': 'finding',
#    'entityId': 'FND-004',
#    'title': 'Medication reconciliation not completed within 24 hours of admission',
#    'orgId': 'ORG-MCLEOD-DILLON'},
#   'countsByEdgeClass': {'operational': 8},
#   'totalEdgeCount': 8},
# ...

# %%
[(item['entity']['entityId'], item['totalEdgeCount']) for item in query4]
# Out:
# [('POL-002', 12),
#  ('STD-002', 10),
#  ('FND-001', 8),
#  ('FND-004', 8),
#  ('STD-007', 8)]
